# %% [markdown]
# # Review Image Labels

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
video_id = 'HIIMcHIJCnM'
frame = 4000

gt = plt.imread(f'../data/processed/{video_id}/gt/{video_id}_{frame}.jpg')
irl = plt.imread(f'../data/processed/{video_id}/irl/{video_id}_{frame}.jpg')
mask = plt.imread(f'../data/processed/{video_id}/mask/{video_id}_{frame}.jpg')

# %%
fig, axs =plt.subplots(1, 3, figsize=(30, 15))
axs[0].imshow(gt)
axs[1].imshow(irl)
axs[2].imshow(mask)
axs[0].axis('off')
axs[1].axis('off')
axs[2].axis('off')
# Out:
# (-0.5, 1279.5, 719.5, -0.5)
